# %% [markdown]
# **which population group is most employed**

# %%
import pandas as pd
import matplotlib.pyplot as plt

file = r"C:\Users\SESPL\bhargav-workspace\Day 34 exploratory da\dataset\Population stats.csv"

df = pd.read_csv(file)

print(df.head)

plt.bar(df.Sector,df['Population(crores)'])

# Naming the x and y axes
plt.xlabel('Sector')  # X-axis label
plt.ylabel('Population (in Crores)')  # Y-axis label

plt.xticks(rotation=90)

plt.show()
# Out:
# <bound method NDFrame.head of                          Sector  Population(crores)  21-25  26-30  31-35  \
# 0                   Agriculture                14.8   2.22   2.22   2.96
# 1     Services (IT and banking)                10.3   1.54   1.54   2.06
# 2                 Manufacturing                 7.1   1.07   1.07   1.42
# 3                  Construction                 6.9   1.04   1.04   1.38
# 4                        Retail                 5.8   0.87   0.87   1.16
# 5      Healthcare and Education                 5.5   0.83   0.83   1.10
# 6  Transportation and Logistics                 3.6   0.54   0.54   0.72
# 7         Public Administration                 2.5   0.37   0.37   0.50
# 8                   Real Estate                 1.8   0.27   0.27   0.36
# 9                        Mining                 1.2   0.18   0.18   0.24
#
#    36-40  41-45  46-50  51-55  56-60
# 0   2.22   1.85   1.85   0.74   0.74
# 1   1.54   1.29   1.29   0.52   0.52
# ...
